# %%
import json
import cv2
import os
import numpy as np


with open('C:/Users/jhkim/OneDrive/Desktop/Annotation/K-TourNet_DS_Menubook_Annotation.json',encoding='UTF8') as f:
    ksign = json.load(f)
ksign.keys()
# Out:
# dict_keys(['4_61203454.jpg165619', '19_843757133.jpg125470', '34_112816952.jpg123319', '40_531188373.jpg106569', '42_104790367.jpg194368', '43_1905295080.jpg123010', '44_176000900.jpg142833', '45_1656386988.jpg169460', '97_2048978614.png852055', '103_1723674888.jpg73695', '104_447716154.jpg122451', '105_42729269.jpg175385', '108_318629778.jpg15919954', '124_137048216.jpg62996', '128_499922655.jpg142065', '129_67795106.jpg167343', '136_196909365.jpg188063', '140_726396764.jpg147896', '143_1506093218.jpg234393', '145_801982356.jpg142949', '146_861395871.jpg367205', '159_1473625962.jpg161547', '164_282656108.jpg117065', '169_695217880.jpg114704', '224_2059601267.jpg164738', '231_2017670163.png566581', '233_83249255.jpg180776', '267_132213736.jpg90484', '275_1426410631.jpg129023', '328_136944252.jpg65767', '342_1168855342.jpg80796', '345_2010815941.jpg154068', '356_125440983.jpg71553', '359_220742587.jpg95465', '362_2057468342.jpg79515', '363_364973509.jpg192034', '444_896055027.jpg157390', '450_1346865802.jpg99902', '466_352567062.jpg42684', '470_1087178027.jpg158917', '471_218368653.jpg240439', '474_394381130.jpg62379', '612_777566436.jpg163506', '643_1410070505.jpg94207', '644_1595231762.jpg80839', '645_6647484.jpg159553', '679_535494472.jpg123422', '685_347658262.jpg162253', '686_346252432.jpg90198', '688_365962386.jpg151526', '689_945684645.jpg109337', '707_111117552.jpg187792', '713_1359971544.jpg177641', '827_692910593.jpg103830', '834_1467723734.jpg223664', '835_951016903.jpg108072', '837_903301887.jpg88308', '850_780375728.jpg246616', '874_245288515.jpg151905', '876_1502757622.jpg132184', '893_320970960.jpg120782', '931_1658581182.jpg103906', '932_1271681586.jpg114805', '949_964175744.jpg167861', '957_1220659288.jpg94272', '980_2000667606.jpg134186', '982_1786715542.jpg148447', '987_299301100.jpg94728', '988_935802994.jpg139120', '990_349446069.jpg166383', '993_1137864203.jpg121264', '1030_547887342.jpg149170', '1044_940402564.jpg93380', '1051_432469338.jpg73033', '1056_33069247.jpg115065', '1093_1206533644.jpg164905', '1099_1064189692.jpg168265', '1135_1774334315.jpg153619', '1137_809170946.jpg109030', '1151_487434489.jpg144712', '1196_488167460.png122116', '1235_219391877.jpg58065', '1244_1500448189.jpg99006', '1245_860892501.png738263', '1256_502502128.jpg93653', '1264_683905851.jpg121280', '1271_1686499064.jpg100214', '1295_999514060.jpg104636', '1313_62146176.jpg140158', '1458_2056037804.jpg76257', '1459_429069630.jpg134464', '1478_1052610503.jpg81147', '1486_1827568609.jpg162676', '1502_211716206.jpg140194', '1503_1490595224.jpg124007', '1510_232902669.jpg118113', '1530_459823801.jpg117328', '1533_150816604.jpg148323', '1540_196774850.jpg106093', '1543_35736456.jpg129254', '1569_1029882570.jpg94217', '1591_1465567328.jpg141070', '1612_734199120.jpg132906', '1617_880870891.jpg167101', '1619_2043001221.jpg130150', '1625_861029874.jpg147174', '1635_762958901.jpg149447', '1637_937791778.jpg148337', '1679_136006137.jpg129551', '1684_544773166.jpg130625', '1685_861709238.jpg101450', '1721_1501336534.jpg5547933', '1734_1914253788.jpg42823', '1741_1176751630.jpg142653', '1760_2014887141.jpg114510', '1763_2098878517.jpg110906', '1801_1088887788.jpg97742', '1807_1091181055.jpg162347', '1818_2103840892.jpg76314', '1847_948953805.jpg134873', '1952_1312093365.jpg100803', '1963_1688170377.jpg109533', '1981_586510826.jpg149029', '2047_734202651.jpg18415', '2051_25476999.jpg99017', '2060_325354394.jpg104594', '2112_344052056.png842837', '2171_593043968.png527376', '2211_744881738.jpg107288', '2226_2097257059.jpg148139', '2334_1551601584.jpg163411', '2336_1787428207.jpg200405', '2339_1269839249.jpg97687', '2348_861715040.jpg196475', '2366_450193623.jpg83511', '2505_1692087080.jpg194116', '2606_2003613800.jpg224463', '2654_217862756.jpg120286', '2661_743944604.jpg113450', '2704_1090424906.jpg149728', '2845_1235525071.jpg151859', '2864_402693721.jpg91242', '2879_208171666.jpg108642', '2969_620628795.jpg108859', '2971_1496898825.jpg175 ...

# %%
text_list={}


i=0
for key in ksign.keys():
    s = ''
    for temp in key:
        if temp == '.':
            break
        s += temp
    try:
        for node in ksign[key]['regions']:
        
            if node['shape_attributes']['name'] == "rect":
                x = node['shape_attributes']['x']
                y = node['shape_attributes']['y']
                w = node['shape_attributes']['width']
                h = node['shape_attributes']['height']
                
            
            if 'annotation_kr' in node['region_attributes'].keys():
                img = cv2.imread('C:/Users/jhkim/OneDrive/Desktop/Annotation/K-TourNet_DS_Menubook_Annotation/'+s+'.jpg')
                img = img[y:y+h,x:x+w]
               
                cv2.imwrite("C:/Users/jhkim/OneDrive/Desktop/Annotation/data/"+str(i)+".jpg", img)
                
                text = node['region_attributes']['annotation_kr']
                text_list[i] = text
#                 cv2.imshow("a",img)
#                 cv2.waitKey(0)
#                 cv2.destroyAllWindows()
                i = int(i)
                i = i+1

                
    except:
        a=1
text_list

# %%
i=8110
for key in ksign.keys():
    s = ''
    for temp in key:
        if temp == '.':
            break
        s += temp
    try:
        for node in ksign[key]['regions']:
        
            if node['shape_attributes']['name'] == "rect":
                x = node['shape_attributes']['x']
                y = node['shape_attributes']['y']
                w = node['shape_attributes']['width']
                h = node['shape_attributes']['height']
                
            
            if 'annotation_kr' in node['region_attributes'].keys():
                img = cv2.imread('C:/Users/jhkim/OneDrive/Desktop/Annotation/K-TourNet_DS_Menubook_Annotation/'+s+'.png')
                img = img[y:y+h,x:x+w]
               
                cv2.imwrite("C:/Users/jhkim/OneDrive/Desktop/Annotation/data/"+str(i)+".jpg", img)
                
                text = node['region_attributes']['annotation_kr']
                text_list[i] = text
#                 cv2.imshow("a",img)
#                 cv2.waitKey(0)
#                 cv2.destroyAllWindows()
                i = int(i)
                i = i+1

                
    except:
        a=1
text_list

# %%
with open('textannotation.json','w',encoding="utf-8") as make_file:
    json.dump(text_list, make_file, ensure_ascii=False,indent="\t")

# %%
with open('C:/Users/jhkim/OneDrive/Desktop/All/K-TourNet_DS_Menubook_All.json',encoding='UTF8') as f:
    ksign = json.load(f)
# Out:
# {'filename': '100125_1636084592.jpg',
#  'size': 108840,
#  'file_attributes': {'dataSource': 'tour POI',
#   'imageSource': '직접촬영',
#   'labeling': '메뉴판, menu book, メニュー, 菜单',
#   'rid': '100125',
#   'title': '이한스시',
#   'addr': '서울 영등포구 당산동1가 256-184',
#   'y': '37.5218879',
#   'x': '126.8962025',
#   'tel': '02-2637-4989',
#   'rlink': 'http://www.redtable.global/restaurant_info.php?city=seoul&rid=100125\n'},
#  'regions': [{'shape_attributes': {'name': 'rect',
#     'x': 521,
#     'y': 299,
#     'width': 230,
#     'height': 29},
#    'region_attributes': {'annotation_kr': '이한 점심특선 7,000'}},
#   {'shape_attributes': {'name': 'polygon',
#     'all_points_x': [527, 534, 764, 758],
#     'all_points_y': [347, 380, 360, 336]},
#    'region_attributes': {'annotation_kr': '이한 모듬초밥 10,000',
#     'annotation_en': 'Assorted Fusion Sushi 10,000',
#     'annotation_cn': '寿司混拼 10,000',
#     'annotation_jp': 'ピュジョン・モドゥムチョバプ(フュージョン寿司の盛り合わせ) 10,000'}},
#   {'shape_attributes': {'name': 'polygon',
#     'all_points_x': [534, 535, 769, 761],
#     'all_points_y': [392, 420, 400, 372]},
#    'region_attributes': {'annotation_kr': '특선 모듬초밥 13,000',
#     'annotation_en': 'Assorted Fusion Sushi 13,000',
#     'annotation_cn': '寿司混拼 13,000',
#     'annotation_jp': 'ピュジョン・モドゥムチョバプ(フュージョン寿司の盛り合わせ) 13,000'}},
#   {'shape_attributes': {'name': 'polygon',
#     'all_points_x': [537, 538, 775, 769, 769],
#     'all_points_y': [428, 450, 430, 408, 409]},
#    'region_attributes': {'annotation_kr': '스폐셜 모듬초밥 16,000',
#     'annotation_en': 'Assorted Fusion Sushi 16,000',
#     'annotation_cn': '寿司混拼 16,000',
#     'annotation_jp': 'ピュジョン・モドゥムチョバプ(フュージョン寿司の盛り合わせ) 16,000'}},
#   {'shape_attributes': {'name': 'rect',
#     'x': 497,
#     'y': 85,
#     'width': 213,
#     'height': 25},
#    'region_attributes': {'annotation_kr': '광어초밥 14,000',
#     'annotation_en': 'gwangeo chobap (Flatfish Sushi) 14,000',
#     'annotation_cn': '扁口鱼寿司 14,000',
#     'annotation_jp': 'クァンオチョバプ(ヒラメ寿司) 14,000'}},
#   {'shape_attributes': {'name': 'polygon',
#     'all_points_x': [539, 545, 784, 779],
#     'all_points_y': [460, 488, 466, 444]},
#    'region_attributes': {'annotation_kr': '생연어초밥 13,000'}},
#   {'shape_attributes': {'name': 'polygon',
#     'all_points_x': [546, 549, 798, 791],
#     'all_points_y': [499, 523, 503, 479]},
#    'region_attributes': {'annotation_kr': '새우초밥 12,000'}}]}

# %%
text_list={}


i=0
for key in ksign.keys():
    s = ''
    for temp in key:
        if temp == '.':
            break
        s += temp
    try:
        for node in ksign[key]['regions']:
        
            if node['shape_attributes']['name'] == "rect":
                x = node['shape_attributes']['x']
                y = node['shape_attributes']['y']
                w = node['shape_attributes']['width']
                h = node['shape_attributes']['height']
                
            
            if 'annotation_kr' in node['region_attributes'].keys():
                img = cv2.imread('C:/Users/jhkim/OneDrive/Desktop/All/'+s+'.jpg')
                img = img[y:y+h,x:x+w]
               
                cv2.imwrite("C:/Users/jhkim/OneDrive/Desktop/All/data/"+str(i)+".jpg", img)
                
                text = node['region_attributes']['annotation_kr']
                text_list[i] = text
#                 cv2.imshow("a",img)
#                 cv2.waitKey(0)
#                 cv2.destroyAllWindows()
                i = int(i)
                i = i+1

                
    except:
        a=1
text_list
# Out:
# {8060: '콩불/순한콩불 6.5',
#  8061: '오삼콩불 7.5',
#  8062: '닭불고기 7.5',
#  8063: '제육볶음 7.5',
#  8064: '보쌈쌈밥 20.0',
#  8065: '비빔밥 6.5',
#  8066: '삼계탕 13.0',
#  8067: '生삼겹 12,000',
#  8068: '목살 150g 12,000',
#  8069: '매콤막창 15,000',
#  8070: '生소시지 7,000',
#  8071: '화요25(375ml) 22,000',
#  8072: '生소시지김치찌개 7000',
#  8073: '김치뚝밥 6,000',
#  8074: '돈불뚝밥 7,000',
#  8075: '새우뚝밥 8,000',
#  8076: '낙지뚝밥 8,000',
#  8077: '고기물냉면/비빔냉면 7,000',
#  8078: '화요 41(200ml) 22,000',
#  8079: '화요 41(375ml) 45,000',
#  8080: '처음처럼 4,000',
#  8081: '하이트 4,000',
#  8082: '상큼포텐 치킨샐러드 6,900',
#  8083: '날아올라 치킨 윙 6,900',
#  8084: '세이보리 감자튀김 3,900',
#  8085: '치즈폭발 어묵고로케 3,900',
#  8086: '엄마찾아 니모튀김 3,900',
#  8087: '로켓발사 새우튀김 3,900',
#  8088: '참치마요주먹밥 1,900',
#  8089: '단짠불고기주먹밥 1,900',
#  8090: '미니강황밥 500',
#  8091: '생맥주 가볍게 (200cc) 1,500',
#  8092: '비빔만두 5,000',
#  8093: '국물만두 5,000',
#  8094: '찐만두 4,500',
#  8095: '갈비만두 5,000',
#  8096: '튀김만두 4,500',
#  8097: '굴림만두 5,500',
#  8098: '새끼만두 4,000',
#  8099: '모듬만두 9,000',
#  8100: '큰모듬만두 13,500',
#  8101: '북촌만둣국 6,500',
#  8102: '얼큰만둣국 7,000',
#  8103: '멸치칼국수 5,500',
#  8104: '피냉면 6,000',
#  8105: '열무냉면 6,500',
#  8106: '비빔국수 5,000',
#  8107: '북촌국시 4,500',
#  8108: '갈릭 치즈 프라이즈 \\5,500',
#  8109: '버팔로 핫윙 \\6,500',
#  8110: '스윗 허니 핫 윙스 \\7,000',
#  8111: '폴리스 비비큐 윙스 \\6,500',
#  8112: '하우스 샐러드 \\6,500',
#  8113: '치킨 마리나라 \\11,000',
#  8114: '스파이시 디아볼로 \\12,000',
#  8115: '쉬림프 로쏘 \\12,900',
#  8116: '치킨 까르보나라 \\12,900 ',
#  8117: '뉴욕 치즈 \\4,500',
#  8118: '페페로니 \\5,000',
#  8119: '화이트 파이 \\5,000',
#  8120: '베이컨 체다 \\5,500',
#  8121: '갓 파더 \\5,500',
#  8122: '스파이시 체다 치킨 \\5,500',
#  8123: '비비큐 치킨 \\5,500',
#  8124: '뉴욕 슈프림 \\5,500',
#  8125: '버섯불고기 \\20,000',
#  8126: '곤드레 돌솥밥 \\11,000',
#  8127: '송이 돌솥밥 \\15,000',
#  8128: '곤드레 등심 해장국 \\11,000',
#  8129: '한우갈비국밥',
#  8130: '연어샐러드 14,900',
#  8131: '카프레제샐러드 16,000',
#  8132: '시저샐러드 16,500',
#  8133: '문어샐러드 16,500',
#  8134: '비프샐러드 19,500',
#  8135: '흑돼지삼겹살 100g 7,200',
#  8136: '흑돼지목살 100g 7,200',
#  8137: '흑돼지작품 6,000',
#  8138: '맥주 4,000won',
#  8139: '소주 4,000won',
#  8140: '막걸리 6,000won',
#  8141: '콜라,사이다 2,000won',
#  8142: '우롱차 2,000won',
#  8143: '치즈케익 3500',
#  8144: '티라미슈 케익  3500',
#  8145: '베이글 2500',
#  8146: '쿠키 1개 800',
#  8147: '밀크 빙수/ 5,500',
#  8148: '녹차 빙수/ 6,500',
#  8149: '커피 빙수/ 6,000',
#  8150: '과일 빙수/ 7,500',
#  8151: '딸기 빙수/ 7,500',
#  8152: '수박 빙수/(계절한정) 7,500',
#  8153: '민물장어\n32.000\n',
#  8154: '된장찌개 6.000',
#  8155: '버섯매운탕칼국수 6,500',
#  8156: '버섯지리탕칼국수 6,500',
#  8157: '서리태 콩 국수  6,500',
#  8158: '왕만두/감자만두 4,500',
#  8159: '갈비만두/물만두 4,500',
#  8160: '쇠고기샤브1접시 7,000',
#  8161: '생감자 수제비 사리 2,500',
#  8162: '생만두사리  2,500',
#  8163: '칼국수면사리 2,000',
#  8164: '미나리/버섯사리 2,000',
#  8165: '조랭이떡 1,000',
#  8166: '추가볶음밥 2,000',
#  8167: '우거지해장국 7,000',
#  8168: '양평해장국 8,000',
#  8169: '우곱탕 9,000',
#  8170: '내장탕 10,000',
#  8171: '파전 10,000',
#  8172: '핫스페셜 38,000\n         33,000',
#  8173: '매운순살 28,000\n         25,000',
#  8174: '매운미니족발 23,000\n             18,000',
#  8175: '반반매운순살 28,000\n             25,000',
#  8176: '영양족발 26,000\n         24,000',
#  8177: '왕새우찜 25,000',
#  8178: '한우 육회 25,000',
#  8179: '한우 떡갈비 25,000 ',
#  8180: '보쌈 15,000',
#  8181: '황태구이 12,000',
#  8182: '심슨탕 \\8,000',
#  8183: '라면사리 \\1,000',
#  8184: '햄&소세지 \\5,000',
#  8185: '칼국수 \\2,000',
#  8186: '공기밥 \\1,000',
#  8187: '심슨부대볶음 \\7,500',
#  8188: '사천제육볶음 \\7,500',
#  8189: '모듬소세지 \\15,000',
#  8190: '돈까스 8,000',
#  8191: '생선까스 8,000',
#  8192: '역촌정식 9,000',
#  8193: '함박스테이크 8,000',
#  8194: '피자돈까스 10,000',
#  8195: '맥주 3,000',
#  8196: '소주 3,000',
#  8197: '음료 1,000',
#  8198: '공기밥 1,000',
#  8199: '쭈삼새 12,000',
#  8200: '쭈꾸미삼겹살 11,000',
#  8201: '쭈꾸미새우 11,000',
#  8202: '매운쭈꾸미 10,000',
#  8203: '날치알볶음밥 2,000',
#  8204: '치즈알볶음밥 3,000',
#  8205: '치즈계란찜 3,000',
#  8206: '계란찜 2,000',
#  8207: '치즈떡 2,000',
#  8208: '삼겹살사리 7,000',
#  8209: '새우사리 7,000',
#  8210: '백짬뽕\n6,000',
#  8211: '삼선짜장\n7,000',
#  8212: '사천짜장\n6,000',
#  8213: '해물우동\n6,000',
#  8214: '굴탕면\n8,000',
#  8215: '해물냉면\n7,000',
#  8216: '홍합짬뽕\n7,000',
#  8217: '냉짬뽕\n7,000',
#  8218: '돼지불백 7000',
#  8219: '해장국 5500',
#  8220: '김치찌개 5500',
#  8221: '된장찌개 5500',
#  8222: '모듬순대 10,000',
#  8223: '순대탕 5,000',
#  8224: '수육 25,000',
#  8225: '포장순대 12,000',
#  8226: '식사용 6,000',
#  8227: '술국 6,000',
#  8228: '소주 4,000',
#  8229: '맥주 4,000',
#  8230: '백세주 7,000',
#  8231: '청하 4,000',
#  8232: '막걸리 3,000',
#  8233: '음료수 1,000',
#  8234: '통 전복 오일 파스타\n26,000',
#  8235: '대파 까르보나라\n18,000',
#  8236: '어부의 해물 파스타\n38,000',
#  8237: '슈림프 로제 파스타\n19,000',
#  8238: '로제 스파게티 14,000',
#  8239: '까르보나라 스파게티 13,000',
#  8240: '수제 망고 푸딩 6,000',
#  8241: '수제 밀크 푸딩 6,000',
#  8242: '연어 회덮밥 \\8,000',
#  8243: '회덮밥 \\8,000',
#  8244: '장어 덮밥(민물) \\18,000',
#  8245: '참치 회덮밥 \\8,000',
#  8246: '날치알롤 \\8,000',
#  8247: '연어롤 \\8,000',
#  8248: '새우롤 \\8,000',
#  8249: '장어롤 \\10,000',
#  8250: '유라쿠 우동 \\4,500',
#  8251: '새우튀김 우동 \\7,500',
#  8252: '유라쿠 냉모밀 \\4,500',
#  8253: '미니우동 \\2,500',
#  8254: '머리고기설농탕 7,000',
#  8255: '설농탕 7,000',
#  8256: '함박스텍 7,000',
#  8257: '돈까스 7,000',
#  8258: '생선까스 8,000',
#  8259: '어린이설농탕 5,000',
#  8260: '수육 20,000',
#  8261: '함경냉면 6,000',
#  8262: '정식 10,000',
#  8263: '특탕 10,000',
#  8264: '에스프레소 Hot 3.0',
#  8265: '아메리카노 Hot 3.5 Ice 3.8',
#  8266: '카페라떼 Hot 4.0 Ice 4.3',
#  8267: '바닐라라떼 Hot 4.5 Ice 4.8',
#  8268: '사과주스 Ice 3.5',
#  8269: '탄산수(페리에) Ice 4.0',
#  8270: '우유 Hot 2.0',
#  8271: '리필(아메리카노) Hot 1.0',
#  8272: '1837 블랙티 6,500',
#  8273: '실버문티 6,500',
#  8274: '그랜드웨딩 6,500',
#  8275: '핫도그\n1500',
#  8276: '닭도리탕 \n大 40,000',
#  8277: '부대찌개 \n大 35,000',
#  8278: '수구레 \n大 35,000',
#  8279: '보신탕 12,000',
#  8280: '동그랑땡 10,000',
#  8281: '라면사리 1,000',
#  8282: '공기밥 1,000',
#  8283: '볶음밥 2,000',
#  8284: '소주 3,000',
#  8285: '맥주 4,000',
#  8286: '청하 4,000',
#  8287: '백세주 7,000',
#  8288: '복분자 10,000',
#  8289: '음료 2,000',
#  8290: '김치찌개 \n25,000',
#  8291: '전골 18,000',
#  8292: '수육 20,000',
#  8293: '무침 30,000',
#  8294: '닭다리살 6,000',
#  8295: '새우 6,500',
#  8296: '베이컨과 훈제연어 7,000',
#  8297: '새우와 캐비어 볶음밥 7,000',
#  8298: '모듬해물 볶음밥 8,000',
#  8299: '샐러드 3,500',
#  8300: '짝대기 마늘빵 2,500',
#  8301: '콜라/사이다 1,000',
#  8302: '하이네켄 5,000',
#  8303: '밀러 5,000',
#  8304: '버드와이저 4,000',
#  8305: '카프리 4,000',
#  8306: '카스 4,000',
#  8307: '레드와인 1잔 5,000',
#  8308: '오코노미야끼 12000',
#  8309: '애비야끼 20000',
#  8310: '아나고야끼 15,000',
#  8311: '스테이크 15000',
#  8312: '시사모야끼 11000',
#  8313: '히레사케 5,000',
#  8314: '어포&아몬드 10000',
#  8315: '대바사끼 9000',
#  8316: '계란말이 7000',
#  8317: '오뎅탕 7000',
#  8318: '새우계란탕 7000',
#  8319: '램모듬꼬치 8,000',
#  8320: '램꼬치 8,000',
#  8321: '램줄기꼬치 7,000',
#  8322: '램갈비살꼬치 9,000',
#  8323: '램등심소금구이 14,000',
#  8324: '램등갈비 14,000',
#  8325: '램고급갈비 14,000',
#  8326: '또띠아와 탄두리소스 2,000',
#  8327: '전통갈비탕 15,000',
#  8328: '갈비우거지탕 14,000',
#  8329: '골동반(궁중비빔밥) 13,000',
#  8330: '육개장 13,000',
#  8331: '(떡)만두탕 11,000',
#  8332: '서울냉면 11,000',
#  8333: '녹차 3,000',
#  8334: '유자차 3,000',
#  8335: '레몬차 3,000',
#  8336: '팥빙수 6,000',
#  8337: '컵빙수 3,500',
#  8338: '미숫가루 3,500',
#  8339: '우유식빵 3,500',
#  8340: '롤치즈식빵 4,500',
#  8341: '크랜베리식빵 4,000',
#  8342: '팥식빵 4,000',
#  8343: '초코식빵 4,500',
#  8344: '시나몬식빵 4,500',
#  8345: '곡물식빵 3,500',
#  8346: '버터식빵 3,500',
#  8347: '밤식빵 4,500',
#  8348: '옥수수식빵 3,500',
#  8349: '오화통삼겹살찜 \\60,000',
#  8350: '광동식팔보기츠 \\49,000',
#  8351: '렁빈따차이 \\50,000',
#  8352: '일품해삼 \\55,000',
#  8353: '해물 누룽지탕 \\38,000',
#  8354: '전가복 \\49,000',
#  8355: '팔보채 \\40,000',
#  8356: '류산슬 \\38,000',
#  8357: '상하이삼선해물 \\45,000',
#  8358: '자연송이안심요리 \\45,000',
#  8359: '연잎 갈비찜 \\15,000',
#  8360: '런치 정식 \\20,000',
#  8361: '런치 스페셜B \\28,000',
#  8362: '런치 스페셜A \\35,000',
#  8363: '참치 런치정식 \\35,000',
#  8364: '런치 한정식 \\35,000',
#  8365: '주말 가족특선B \\28,000',
#  8366: '주말 가족특선A \\35,000',
#  8367: '주말 스페셜 \\43,000',
#  8368: '사시미 정식 \\45,000',
#  8369: '삿뽀로 모둠스페셜 \\65,000',
#  8370: '디너 한정식 \\65,000',
#  8371: '사시미특선 \\90,000',
#  8372: '삿뽀로 VIP스페셜 \\110,000',
#  8373: '참치 스페셜B \\65,000',
#  8374: '참치 스페셜A \\90,000',
#  8375: '참치 골드 \\110,000',
#  8376: '초밥 \\20,000',
#  8377: '특초밥 \\30,000',
#  8378: '생우럭 지리/탕 \\15,000',
#  8379: '생대구 지리/탕 \\15,000',
#  8380: '활어 회덮밥 \\12,000',
#  8381: '우동정식 \\12,000',
#  8382: '소바정식 \\12,000',
#  8383: '전복죽 \\20,000',
#  8384: '육회비빔밥 \n\\10,000',
#  8385: '안심한우샤브샤브\n\\13,000',
#  8386: '안심불고기정식\n\\10,000',
#  8387: '한우모듬 \\60,000',
#  8388: '등심 \\42,000',
#  8389: '통등심 \\80,000',
#  8390: '불고기 \\13,000',
#  8391: '초정냉면 \\6,000',
#  8392: '와인 \\40,000',
#  8393: '초정냉면 \\4,000',
#  8394: '된장국수 \\3,000',
#  8395: '된장찌개 \\2,000',
#  8396: '육회 \\25,000',
#  8397: '육사시미 \\25,000',
#  8398: '차돌박이 \\30,000',
#  8399: '주류 반입 세팅비 테이블 \\10,000',
#  8400: '백설사과 7,800',
#  8401: '이상한 나라의 초콜렛 9,300',
#  8402: '베이비 드링키스 8,700',
#  8403: '春,30 9,700',
#  8404: '명이 마늘 보쌈 (中)\n\\25,000',
#  8405: '명이 추가 \\4,000',
#  8406: '국수만두전골 \\19,000',
#  8407: '훈제삼겹살 \\14,000',
#  8408: '민물장어 \n27,000',
#  8409: '바다장어\n19,000',
#  8410: '돌솥장어덮밥\n10,000',
#  8411: '장메추탕\n10,000',
#  8412: '장어매운탕\n12,000',
#  8413: '메기매운탕\n10,000',
#  8414: '소주 10,000',
#  8415: '화요25 25,000',
#  8416: '설화 60,000',
#  8417: '화랑 22,000',
#  8418: '복분자 22,000',
#  8419: '매취순 16,000',
#  8420: '백세주 16,000',
#  8421: '천년약속 17,000',
#  8422: '정종대포 9,000',
#  8423: '쿠보타 만쥬(720ml) 220,000',
#  8424: '쿠보타 센쥬(720ml) 85,000',
#  8425: '준마이 다이긴죠(720ml) 80,000',
#  8426: '월계관 준마이(750ml) 40,000',
#  8427: '나마죠조(300ml) 20,000',
#  8428: '정종 도꾸리 12,000',
#  8429: '히레사케 12,000',
#  8430: '전통갈비탕 15,000',
#  8431: '갈비우거지탕 14,000',
#  8432: '골둥반(궁중비빔밥) 13,000',
#  8433: '육개장 13,000',
#  8434: '(떡)만두탕 11,000',
#  8435: '서울냉면(물/비빔/온면) 11,000',
#  8436: '콜라, 스프라이트 - 2,000',
#  8437: '식혜 - 2,000',
#  8438: '커피 - 3,000',
#  8439: '안동소주 - 12,000',
#  8440: '화요 25 - 28,000',
#  8441: '화요 41 - 42,000',
#  8442: '일품 진로 - 28,000',
#  8443: '문배술 - 18,000',
#  8444: '카스 - 6,000',
#  8445: '생맥주(아사히) - 8,000',
#  8446: '참이슬, 처음처럼 - 5,000',
#  8447: '서울의 밤 - 9,000',
#  8448: '홍소육 12000',
#  8449: '새우빵 15000',
#  8450: '오향장육 12000',
#  8451: '탕수육 10000',
#  8452: '자장면 4000',
#  8453: '짬뽕 5000',
#  8454: '군만두 5000',
#  8455: '물만두 5000',
#  8456: '맥주 3000',
#  8457: '소주 3000',
#  8458: '스시코스 35,000',
#  8459: '스시코스 65,000',
#  8460: '스시오마카세 80,000',
#  8461: '스시 44,000',
#  8462: '스시 66,000',
#  8463: '오마카세 88,000',
#  8464: '스시 12종 33,000',
#  8465: '크림커리우동 \n11.0',
#  8466: '라유우동 \n11.0',
#  8467: '매콤해물탕면 \n13.0',
#  8468: '게살복음밥 \n12.0',
#  8469: '가츠동 \n12.0',
#  8470: '회덮밥 \n12.0',
#  8471: '나이아가라 딸기 (8000)',
#  8472: '고마워케이크 (생크림,9000)',
#  8473: '딸기 사랑해케이크 (딸기 티라미슈, 9500)',
#  8474: '딸기 기분좋아케이크 (크림치즈, 9500)',
#  8475: '촉촉해 케이크 (생크림+초코시트, 9000)',
#  8476: '참명란 비빔밥 \n8,000',
#  8477: '장아찌 불고기밥 \n8,000',
#  8478: '아사이베리 쥬스 1000ml\n\\12,900',
#  8479: '아사이베리 쥬스 175ml\n\\3,400',
#  8480: '오징어튀김 3,500',
#  8481: '새우튀김 3,500',
#  8482: '나쵸감자튀김 5,000',
#  8483: '순살치킨(가라아게) 6,000',
#  8484: '모듬튀김 7,000',
#  8485: '레몬에이드 4990',
#  8486: '자몽에이드 4990',
#  8487: '오렌지에이드 4990',
#  8488: '인삼한뿌리 5990',
#  8489: '청포도한송이 5990',
#  8490: '크리스마스 석류 5990',
#  8491: '써머스트로베리 4990',
#  8492: '써머 망고 4990',
#  8493: '진저에이드 5990',
#  8494: '모히토 5990',
#  8495: '방배동 아란치니\n8,000',
#  8496: '북한산 프라이즈\n10,000',
#  8497: '강북 타코\n10,000',
#  8498: '환타 2,000',
#  8499: '탄산수 3,000',
#  8500: '씨푸레제 \n14.0',
#  8501: '시저샐러드 \n13.5',
#  8502: '루꼴라 피자 \n17.5',
#  8503: '고르곤졸라 피자 \n18.0',
#  8504: '풍기 피자Ⅱ \n17.5',
#  8505: '라구 피자 \n13.0',
#  8506: '마르게리파 피자 \n16.5',
#  8507: '비포선라이즈 크레페 16,000',
#  8508: '투스칸 에그 베네딕트 17,000',
#  8509: '새우 & 버섯 크림소스 크레페 18,000',
#  8510: '머쉬룸 에그 베네딕트 17,000',
#  8511: '시금치 & 새우 프리타타 18,000',
#  8512: '키쉬 로렌 17,000',
#  8513: '오븐 수플레 팬케익 16,000',
#  8514: '브리오쉬 프렌치 토스트 16,000',
#  8515: '볼로네제 라자냐 20,000',
#  8516: '토마토 미트볼 스튜 18,000',
#  8517: '계란 3,000',
#  8518: '구운 치아바타 3,000',
#  8519: '잉글리쉬 머핀 2,000',
#  8520: '허니 로스티드 포테이토 5,000',
#  8521: '베이컨 2,000',
#  8522: '소스(아이올리,홀렌데이즈) 1,000',
#  8523: '콘 4,000',
#  8524: '컵 4,000',
#  8525: '포장박스 17,000',
#  8526: '포장박스 24,000',
#  8527: '포장박스 34,000',
#  8528: '포장박스 58,000',
#  8529: '아메리카노 3,800',
#  8530: '카페라떼/카푸치노 4,000',
#  8531: '핫초코 4,500',
#  8532: '아포가또(밀크) 4,500',
#  8533: '초계국수 정식 8,000',
#  8534: '닭개장 정식 7,000',
#  8535: '닭볶음탕 정식 9,000',
#  8536: '순대국밥 8.0',
#  8537: '고기국밥 8.0',
#  8538: '고기국수 8.0',
#  8539: '순대정식 11.0',
#  8540: '고기정식 11.0',
#  8541: '곰탕 보통 10,000',
#  8542: '수육 50,000',
#  8543: '20,000 스무곰',
#  8544: '가마아게우동\n\\3,500',
#  8545: '자루우동\n\\3,500',
#  8546: '기츠네우동\n\\4,800',
#  8547: '멘타이가마타마\n\\6,500',
#  8548: '카레우동\n\\6,200',
#  8549: '니꾸타마 붓가케\n\\7,000',
#  8550: '오뎅우동 \n\\5,500',
#  8551: '돈코츠우동 매운맛\n\\7,200',
#  8552: '규동(쇠고기덮밥)\n\\7,000',
#  8553: '치킨마요동\n\\7,000',
#  8554: '치킨카레돈부리\n\\7,200',
#  8555: '클래식 5.5',
#  8556: '크리스피치킨 4.7',
#  8557: '치즈 5.9',
#  8558: '베이컨 치즈 6.9',
#  8559: '피츠 6.5',
#  8560: '코울슬로 5.9',
#  8561: '해쉬포테이토 6.5',
#  8562: '써니 6.5',
#  8563: '칠리치즈 7.9',
#  8564: '더블더블 8.9',
#  8565: '존슨 6.7',
#  8566: '패티 2.0',
#  8567: '베이컨 1.0',
#  8568: '치즈 1.0',
#  8569: '계란 1.0',
#  8570: '전통 녹두전 9,000',
#  8571: '메밀전 7,000',
#  8572: '편육 15,000',
#  8573: '오두산 메밀탁주 5,000',
#  8574: '탁주 한잔 1,000',
#  8575: '맛 정식 38,000',
#  8576: '멋 정식 55,000',
#  8577: '벗 정식 78,000',
#  8578: '명인 정식 120,000',
#  8579: '상견례 정식 50,000',
#  8580: '런치 코스 35,000',
#  8581: '숯불 떡갈비 반상 28,000',
#  8582: '보리굴비 반상 33,000',
#  8583: '어묵떡볶이 5,000',
#  8584: '모둠튀김어묵 한접시 5,000',
#  8585: '곰탕 보통 10,000',
#  8586: '수육 중 30,000',
#  8587: '창스 스파이시 치킨\n17,000',
#  8588: '크리스피 허니 치킨\n17,000',
#  8589: '쿵파오 치킨 \n18,000',
#  8590: '세사미 치킨 \n19,000',
#  8591: '스위트 & 사워 치킨 \n17,000',
#  8592: '아몬드 & 캐슈넛 치킨 \n19,000',
#  8593: '칸토니즈 스타일 레몬 치킨\n17,000',
#  8594: '오렌지 필 치킨\n19,000',
#  8595: '진저 치킨 위드 브로콜리\n19,000',
#  8596: '무 구 가이 판\n23,000',
#  8597: '몽골리안 비프\n28,000',
#  8598: '비프 위드 브로콜리\n27,000',
#  8599: '페퍼 스테이크\n28,000',
#  8600: '오렌지 필 비프\n27,000',
#  8601: '비프 알라 시추안\n25,000',
#  8602: '스위트 & 사워 포크\n18,000',
#  8603: '파이어 갈릭 포크\n19,000',
#  8604: '스위트 크리스피 포크\n19,000',
#  8605: '애플비트 주스 7.0',
#  8606: '그린케일 주스 7.0',
#  8607: '청포도 주스 6.5',
#  8608: '오렌지 주스 6.5',
#  8609: '토마토 주스 6.5',
#  8610: '소고기 냉채 \n\\12,900',
#  8611: '해물 궁중 만두 \n\\9,900',
#  8612: '해물파전 \n\\9,900',
#  8613: '돌솥 불고기 비빔밥\n\\10,900',
#  8614: '일품 강된장 비빔밥\n\\8,900',
#  8615: '차돌된장찌개\n\\9,900',
#  8616: '멀티플컵\n\\10,000',
#  8617: '쿼트컵\n\\13,000',
#  8618: '파티컵\n\\17,500',
#  8619: '프랜즈컵\n\\20,000',
#  8620: '싱글컵/콘\n\\2,700',
#  8621: '싱글퀸컵\n\\3,500',
#  8622: '더블컵/콘\n\\4,500',
#  8623: '트리플컵\n\\6,700',
#  8624: '오크리프 그린 샐러드 11,000',
#  8625: '유기농 아이스플란트 샐러드 13,000',
#  8626: '아이스 플랜트 오픈 샌드위치 12,000',
#  8627: '허브 닭가슴살 깻잎 리조또 16,000',
#  8628: '쉬림프 크림 리조또 16,000',
#  8629: '흑임자 버섯 크림 리조또 18,000',
#  8630: '허브 삽결살 플레터 18,000',
#  8631: '유자 비가라드 허브치킨 스테이크 18,000',
#  8632: '할라피뇨 오일 파스타 14,000',
#  8633: '쭈꾸미 오일 파스타 14,000',
#  8634: '칠리고추 토마토 파스타 15,000',
#  8635: '계란 노른자 까르보나라 15,000',
#  8636: '로제 파스타 16,000',
#  8637: '인절미 고르곤졸라 19,000',
#  8638: '씨푸드 토마토 피자 19,000',
#  8639: '베이비 시금치 포테이토 피자 19,000',
#  8640: '인삼 엔초비 콜드 파스타 15,000',
#  8641: '순두부찌개 9,000',
#  8642: '된장찌개 8,000',
#  8643: '옛날 청국장 9,000',
#  8644: '두부 스테이크 10,000',
#  8645: '도토리 묵채밥 8,000',
#  8646: '',
#  8647: '',
#  8648: '',
#  8649: '',
#  8650: '',
#  8651: '할머니국수 5,000',
#  8652: '두부국수 5,500',
#  8653: '유부김치국수 6,000',
#  8654: '오뎅국수 6,500',
#  8655: '비빔국수 5,500',
#  8656: '매운비빔국수 6,500',
#  8657: '고기국수 7,500',
#  8658: '명태회비빔국수 8,000',
#  8659: '명태물회국수 8,000',
#  8660: '궁중비빔국수 6,500',
#  8661: '만두국수 6,500',
#  8662: '검은콩국수 7,500',
#  8663: '열무국수 7,500',
#  8664: '토코 톤코츠 라멘(간장소스) 8,000',
#  8665: '토코 시오 톤코츠 라멘(담백한소스) 8,000',
#  8666: '쇼유 톤코츠 라멘(간장소스) 8,000',
#  8667: '시오 톤코츠 라멘(담백한 소스) 8,000',
#  8668: '머쉬룸 크림 리조또 14,500',
#  8669: '보리 베이컨 리조또 13,000',
#  8670: '스테이크 찹 도리아 13,500',
#  8671: '스파이시 치킨 도리아 12,000',
#  8672: '영양 갈비탕 10,000',
#  8673: '매콤한 갈비찜 32,000',
#  8674: '사골 육개장 9,000',
#  8675: '차돌 된장 뚝배기 8,500',
#  8676: '된장뚝배기 5,500',
#  8677: '등갈비김치뚝배기 11,000',
#  8678: '물냉면 8,000',
#  8679: '비빔냉면 8,000',
#  8680: '회냉면 9,000',
#  8681: '국밥 9,000',
#  8682: '떡만두국/떡국/만두국 9,000',
#  8683: '갈비탕 11,000',
#  8684: '만두 8,000',
#  8685: '에크멕 6,000',
#  8686: '라바시 5,000',
#  8687: '케르반 팔라펠 16,000',
#  8688: '세브제 타바 29,000',
#  8689: '요구르트르 사르마 21,000',
#  8690: '소테 치킨 19,000',
#  8691: '오늘의 쉐프 메뉴 19,000',
#  8692: '안동찜닭 23,000',
#  8693: '공기밥 1,000',
#  8694: '떡사리 2,000',
#  8695: '당면사리 3,000',
#  8696: '삼계탕 \n14,000',
#  8697: '떡갈비주물찜(小) 17,000',
#  8698: '소고기라이스 \\9,000',
#  8699: '해물라이스 \\9,000',
#  8700: '콤비라이스 \\10,000',
#  8701: '소고기소바 \\9,000',
#  8702: '해물소바 \\9,000',
#  8703: '오코마요 소바 \\9,000',
#  8704: '콤비소바 \\10,000',
#  8705: '돈코츠라멘 \\7,000',
#  8706: '돈까스세트 \\8,500',
#  8707: '치즈돈까스세트 \\9,500',
#  8708: '냄비돈까스 \\8,000',
#  8709: '치즈냄비돈까스 \\8,500',
#  8710: '김치나베우동 \\7,000',
#  8711: '오뎅꼬치김치우동 \\8,000',
#  8712: '오뎅꼬치우동 \\6,000',
#  8713: '새우튀김우동 \\6,000',
#  8714: '냉모밀 \\7,000',
#  8715: '비빔모밀 \\7,000',
#  8716: '멀티플컵 \\10,000',
#  8717: '쿼트컵 \\13,000',
#  8718: '파티컵 \\17,500',
#  8719: '프랜즈컵 \\20,000',
#  8720: '싱글컵/콘 \\2,700',
#  8721: '싱글퀸컵 \\3,500',
#  8722: '더블컵/콘 \\4,500',
#  8723: '트리플컵 \\6,700',
#  8724: '카페 아메리카노\n4,500',
#  8725: '카푸치노 5,000',
#  8726: '카페라떼 5,000',
#  8727: '바닐라 라떼 5,500',
#  8728: '카페모카\n5,500',
#  8729: '캐러멜 마끼아또\n5,900',
#  8730: '카페 사케라또 \n6,000',
#  8731: '카페 아포가또 \n7,700',
#  8732: '마누카 허니 비엔나\n6,100',
#  8733: '에스프레소\n3,800',
#  8734: '에스프레소 마끼아또\n4,200',
#  8735: '에스프레소 콘 파나\n4,200',
#  8736: '스페셜티 싱글 오리진\n4,800',
#  8737: '레몬 코코넛 퀸즈 프라페 5.4',
#  8738: '민트 초코 퀸즈 프라페 5.4',
#  8739: '그린티 퀸즈 프라페 5.4',
#  8740: '딸기 코코넛 퀸즈 프라페 5.8',
#  8741: '초코브라우니 퀸즈 프라페 5.8',
#  8742: '아사이베리 스무디 5.8',
#  8743: '망고 스무디 5.8',
#  8744: '딸기 스무디 5.8',
#  8745: '아사이볼 (s) 7.5',
#  8746: '아메리카노 \\4,000',
#  8747: '토이셔 초콜릿 커피 \\6,800',
#  8748: '오리지널 초콜릿 음료 \\6,500',
#  8749: '샴페인 트러플 초콜릿(10g) +아메리카노 \\5,800',
#  8750: '샴페인 트러플 초콜릿(14g)+ 아메리카노 \\6,800',
#  8751: '안심쌀국수\n11,000',
#  8752: '차돌박이와 홍두깨 쌀국수\n9,000',
#  8753: '닭고기 쌀국수\n9,000',
#  8754: '해산물 쌀국수\n9,000',
#  8755: '해물 사천 쌀국수\n9,000',
#  8756: '가츠동 \\7,500',
#  8757: '더블가츠동 \\9,500',
#  8758: '가츠가라아게동 \\8,500',
#  8759: '치즈가츠동 \\9,000',
#  8760: '치킨가츠동 \\8,500',
#  8761: '고추가츠동 \\8,500',
#  8762: '규동 \\8,500',
#  8763: '가끼아게동 中 \\8,000',
#  8764: '낫또동 \\7,000',
#  8765: '전주모주 7,000',
#  8766: '검은콩 막걸리 7,000',
#  8767: '복분자 12,000',
#  8768: '소주 4,000',
#  8769: '맥주 4,000',
#  8770: '음료 2,000',
#  8771: '자몽에이드  \\5000',
#  8772: '왕새우 팟타이 16,000',
#  8773: '미고랭 15,000',
#  8774: '생어거스틴 누들 14,000',
#  8775: '퍼싸오 13,000',
#  8776: '꾸웨이띠오 10,000',
#  8777: '퍼보 10,000',
#  8778: '비프 레드 커리 16,000',
#  8779: '치킨 그린 커리 16,000',
#  8780: '전통갈비구이 반상 22,000',
#  8781: '등심불고기구이 반상 21,000',
#  8782: '죽생 전복 스프 1.5',
#  8783: '산라 스프 1.9',
#  8784: '대게살 스프 1.0',
#  8785: '매콤한 오이무침 \n\\8,000',
#  8786: '사천식 닭고기 냉채 \\12,000',
#  8787: '1++ 한우채끝등심구이 반상 龍 56,000',
#  8788: '전통갈비구이 반상 龍 49,000',
#  8789: '등심불고기구이 반상 龍\n44,000',
#  8790: '유황오리진흙구이 \\48,000',
#  8791: '아몬드라떼 \n\\2,500',
#  8792: '아메리카노 \\1,500',
#  8793: '카페라떼 \\2,500',
#  8794: '코카-콜라 \\1,700',
#  8795: '코카-콜라 제로 \\1,700',
#  8796: '환타오렌지 \\1,700',
#  8797: '스프라이트 \\1,700',
#  8798: '핫초코 \\2,000',
#  8799: '미닛메이드 \\2,500',
#  8800: '생수(순수) \\1,200',
#  8801: '타키토스 14,0',
#  8802: '멕시칸 시저 샐러드 15,0',
#  8803: '엔칠라다 14.0',
#  8804: '치킨 윙 13,0',
#  8805: '화동생돼지갈비 16,000',
#  8806: '화동수제갈비 250g 15,000',
#  8807: '국내산생목살 14,000',
#  8808: '생오겹살 16,000',
#  8809: '한우우설수육 400g 26,000',
#  8810: '매운돼지갈비찜 500g 16,000',
#  8811: '김치찌개 7,000',
#  8812: '소바냉면 8,000',
#  8813: '막국수(물/비빔) 8,000',
#  8814: '해물된장라면 7,000',
#  8815: '갈비탕 8,000',
#  8816: '제육숙주돌판불고기 7,000',
#  8817: '한우소머리곰탕 9,000',
#  8818: '주말/공휴일 16,900',
#  8819: '취학아동 9,000',
#  8820: '미취학아동 6,000',
#  8821: '평일 점심 12,900',
#  8822: '골뱅이무침 12,900',
#  8823: '해물파전 10,000',
#  8824: '동태전 10,00',
#  8825: '날치알주먹밥 3,000',
#  8826: '모주 1,500',
#  8827: '볶음밥 2,000',
#  8828: '공기밥 1,000',
#  8829: '계란찜 1,000',
#  8830: '소주 3,000',
#  8831: '맥주 4,000',
#  8832: '막걸리 3,000',
#  8833: '음료 1,000',
#  8834: '사천식 돈등심 덮밥 14,000'}

# %%
i=8060
for key in ksign.keys():
    s = ''
    for temp in key:
        if temp == '.':
            break
        s += temp
    try:
        for node in ksign[key]['regions']:
        
            if node['shape_attributes']['name'] == "rect":
                x = node['shape_attributes']['x']
                y = node['shape_attributes']['y']
                w = node['shape_attributes']['width']
                h = node['shape_attributes']['height']
                
            
            if 'annotation_kr' in node['region_attributes'].keys():
                img = cv2.imread('C:/Users/jhkim/OneDrive/Desktop/All/'+s+'.png')
                img = img[y:y+h,x:x+w]
               
                cv2.imwrite("C:/Users/jhkim/OneDrive/Desktop/All/data/"+str(i)+".jpg", img)
                
                text = node['region_attributes']['annotation_kr']
                text_list[i] = text
#                 cv2.imshow("a",img)
#                 cv2.waitKey(0)
#                 cv2.destroyAllWindows()
                i = int(i)
                i = i+1

                
    except:
        a=1
text_list

# %%
# json.dumps(text_list)
with open('textall.json','w',encoding="utf-8") as make_file:
    json.dump(text_list, make_file, ensure_ascii=False,indent="\t")
